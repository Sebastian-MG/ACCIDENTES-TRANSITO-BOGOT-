# %%
# importar librerias necesarias
import pandas as pd
import datetime
import numpy as np

# %%
#leer datos
datos_accidentes =  "2015_2019_siniestralidad_vial.xlsx"
# leer datos de accidentes hoja siniestros
accidentes_siniestros= pd.read_excel("2015_2019_siniestralidad_vial.xlsx", sheet_name="SINIESTROS")
accidentes_actor_vial = pd.read_excel("2015_2019_siniestralidad_vial.xlsx", sheet_name="ACTOR_VIAL")
accidentes_vehiculos = pd.read_excel("2015_2019_siniestralidad_vial.xlsx", sheet_name="VEHICULOS")
accidentes_hipotesis = pd.read_excel("2015_2019_siniestralidad_vial.xlsx", sheet_name="HIPOTESIS")

# %%
accidentes_siniestros.head()
# Out:
#    CODIGO_SINIESTRO       FECHA      HORA     GRAVEDAD        CLASE  \
# 0           4401423  01/01/2015  09:45:00  Con Heridos       Choque
# 1           4401425  01/01/2015  13:25:00   Solo Daños       Choque
# 2           4401430  01/01/2015  07:15:00  Con Heridos  Volcamiento
# 3           4401433  01/01/2015  20:30:00   Solo Daños       Choque
# 4           4401437  01/01/2015  12:50:00   Solo Daños       Choque
#
#   CHOQUE_CON OBJETO_FIJO          DIRECCION  TOTAL_MUERTOS  TOTAL_HERIDOS  \
# 0   Vehiculo         NaN    CL 66A-KR 76 02              0              2
# 1   Vehiculo         NaN  CL 143A-KR 142 02              0              0
# 2        NaN         NaN  KR 19D-CL 62 S 02              0              1
# 3   Vehiculo         NaN      AK 7-CL 43 33              0              0
# 4   Vehiculo         NaN   DG 77A-AK 18D 02              0              0
#
#         LOCALIDAD  DISENO_LUGAR
# 0        Engativá  Interseccion
# 1            Suba  Tramo de Via
# 2  Ciudad Bolívar  Tramo de Via
# 3       Chapinero  Tramo de Via
# 4  Ciudad Bolívar  Tramo de Via

# %%
accidentes_actor_vial.head()
# Out:
#    CODIGO_SINIESTRO       FECHA  CONDICION  ESTADO  EDAD       SEXO   VEHICULO
# 0           4401420  01/01/2015  CONDUCTOR   ILESO  20.0  MASCULINO  4401420-2
# 1           4401429  01/01/2015     PEATON  HERIDO  28.0  MASCULINO        NaN
# 2           4401442  01/01/2015   PASAJERO  HERIDO  22.0  MASCULINO  4401442-1
# 3           4401442  01/01/2015     PEATON  HERIDO  57.0  MASCULINO        NaN
# 4           4401423  01/01/2015     PEATON  HERIDO  19.0   FEMENINO        NaN

# %%
accidentes_vehiculos.head()
# Out:
#    CODIGO_SINIESTRO       FECHA   VEHICULO        CLASE    SERVICIO ENFUGA
# 0           4401429  01/01/2015  4401429-1     Microbus     Publico      N
# 1           4401449  01/01/2015  4401449-1  Motocicleta  Particular      N
# 2           4401453  01/01/2015  4401453-1          Bus     Publico      N
# 3           4401453  01/01/2015  4401453-2    Automovil     Publico      N
# 4           4401447  01/01/2015  4401447-1    Automovil     Publico      N

# %%
accidentes_hipotesis.head()
# Out:
#    CODIGO_SINIESTRO       FECHA CODIGO_CAUSA  \
# 0           4401449  01/01/2015          114
# 1           4401447  01/01/2015          121
# 2           4401438  01/01/2015          157
# 3           4401429  01/01/2015          116
# 4           4401433  01/01/2015          121
#
#                           DESCRIPCION  CODIGO_CAUSA2 DESCRIPCION2
# 0                 EMBRIAGUEZ APARENTE            NaN          NaN
# 1  NO MANTENER DISTANCIA DE SEGURIDAD            NaN          NaN
# 2                                OTRA            NaN          NaN
# 3                 EXCESO DE VELOCIDAD            NaN          NaN
# 4  NO MANTENER DISTANCIA DE SEGURIDAD            NaN          NaN

# %%
# verificar tipo de datos de cada columna del dataframe
accidentes_siniestros.dtypes
# Out:
# CODIGO_SINIESTRO     int64
# FECHA               object
# HORA                object
# GRAVEDAD            object
# CLASE               object
# CHOQUE_CON          object
# OBJETO_FIJO         object
# DIRECCION           object
# TOTAL_MUERTOS        int64
# TOTAL_HERIDOS        int64
# LOCALIDAD           object
# DISENO_LUGAR        object
# dtype: object

# %%
accidentes_actor_vial.dtypes
# Out:
# CODIGO_SINIESTRO      int64
# FECHA                object
# CONDICION            object
# ESTADO               object
# EDAD                float64
# SEXO                 object
# VEHICULO             object
# dtype: object

# %%
accidentes_vehiculos.dtypes
# Out:
# CODIGO_SINIESTRO     int64
# FECHA               object
# VEHICULO            object
# CLASE               object
# SERVICIO            object
# ENFUGA              object
# dtype: object

# %%
accidentes_hipotesis
# Out:
#         CODIGO_SINIESTRO       FECHA CODIGO_CAUSA  \
# 0                4401449  01/01/2015          114
# 1                4401447  01/01/2015          121
# 2                4401438  01/01/2015          157
# 3                4401429  01/01/2015          116
# 4                4401433  01/01/2015          121
# ...                  ...         ...          ...
# 206664          10507450  31/12/2019          121
# 206665          10507440  31/12/2019          112
# 206666          10507407  31/12/2019          157
# 206667          10507407  31/12/2019          143
# 206668          10507386  31/12/2019          114
#
#                                          DESCRIPCION  CODIGO_CAUSA2  \
# 0                                EMBRIAGUEZ APARENTE            NaN
# 1                 NO MANTENER DISTANCIA DE SEGURIDAD            NaN
# 2                                               OTRA            NaN
# 3                                EXCESO DE VELOCIDAD            NaN
# 4                 NO MANTENER DISTANCIA DE SEGURIDAD            NaN
# ...                                              ...            ...
# 206664            NO MANTENER DISTANCIA DE SEGURIDAD            NaN
# 206665                           DESOBEDECER SEÑALES            NaN
# 206666                                          OTRA            NaN
# 206667  PONER EN MARCHA UN VEHICULO SIN PRECAUCIONES            NaN
# 206668                           EMBRIAGUEZ APARENTE            NaN
#
#        DESCRIPCION2
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 206664          NaN
# 206665          NaN
# 206666          NaN
# 206667          NaN
# 206668          NaN
#
# [206669 rows x 6 columns]

# %%
import datetime
# convertir fecha de accidentes_siniestros de string a datetime
fecha_str = "12/01/1999"
datetime.datetime.strptime(fecha_str, "%d/%m/%Y").strftime("%Y-%m-%d")
# Out:
# '1999-01-12'

# %%
# se converte la fecha de 12/12/1999 a 1999/12/12
accidentes_siniestros["FECHA"] = list(map(lambda x: datetime.datetime.strptime(x,'%d/%m/%Y').strftime('%Y-%m-%d'), accidentes_siniestros['FECHA']))
# se convierte a datetime
accidentes_siniestros["FECHA"] =  pd.to_datetime(accidentes_siniestros["FECHA"], infer_datetime_format=True,)

# %%
accidentes_siniestros.head()
# Out:
#    CODIGO_SINIESTRO      FECHA      HORA     GRAVEDAD        CLASE CHOQUE_CON  \
# 0           4401423 2015-01-01  09:45:00  Con Heridos       Choque   Vehiculo
# 1           4401425 2015-01-01  13:25:00   Solo Daños       Choque   Vehiculo
# 2           4401430 2015-01-01  07:15:00  Con Heridos  Volcamiento        NaN
# 3           4401433 2015-01-01  20:30:00   Solo Daños       Choque   Vehiculo
# 4           4401437 2015-01-01  12:50:00   Solo Daños       Choque   Vehiculo
#
#   OBJETO_FIJO          DIRECCION  TOTAL_MUERTOS  TOTAL_HERIDOS  \
# 0         NaN    CL 66A-KR 76 02              0              2
# 1         NaN  CL 143A-KR 142 02              0              0
# 2         NaN  KR 19D-CL 62 S 02              0              1
# 3         NaN      AK 7-CL 43 33              0              0
# 4         NaN   DG 77A-AK 18D 02              0              0
#
#         LOCALIDAD  DISENO_LUGAR
# 0        Engativá  Interseccion
# 1            Suba  Tramo de Via
# 2  Ciudad Bolívar  Tramo de Via
# 3       Chapinero  Tramo de Via
# 4  Ciudad Bolívar  Tramo de Via

# %%
# se obtiene el dia de la semana mediante la fecha en datetime
accidentes_siniestros["DIA_SEMANA"] = accidentes_siniestros["FECHA"].dt.day_name()
# NOTA: Cambiar dias a Español

# %%
accidentes_siniestros.head()
# Out:
#    CODIGO_SINIESTRO      FECHA      HORA     GRAVEDAD        CLASE CHOQUE_CON  \
# 0           4401423 2015-01-01  09:45:00  Con Heridos       Choque   Vehiculo
# 1           4401425 2015-01-01  13:25:00   Solo Daños       Choque   Vehiculo
# 2           4401430 2015-01-01  07:15:00  Con Heridos  Volcamiento        NaN
# 3           4401433 2015-01-01  20:30:00   Solo Daños       Choque   Vehiculo
# 4           4401437 2015-01-01  12:50:00   Solo Daños       Choque   Vehiculo
#
#   OBJETO_FIJO          DIRECCION  TOTAL_MUERTOS  TOTAL_HERIDOS  \
# 0         NaN    CL 66A-KR 76 02              0              2
# 1         NaN  CL 143A-KR 142 02              0              0
# 2         NaN  KR 19D-CL 62 S 02              0              1
# 3         NaN      AK 7-CL 43 33              0              0
# 4         NaN   DG 77A-AK 18D 02              0              0
#
#         LOCALIDAD  DISENO_LUGAR DIA_SEMANA
# 0        Engativá  Interseccion   Thursday
# 1            Suba  Tramo de Via   Thursday
# 2  Ciudad Bolívar  Tramo de Via   Thursday
# 3       Chapinero  Tramo de Via   Thursday
# 4  Ciudad Bolívar  Tramo de Via   Thursday

# %%
# crear columna del día del mes
accidentes_siniestros["DIA_MES"] = accidentes_siniestros["FECHA"].dt.month_name()
accidentes_siniestros.head()
# Out:
#    CODIGO_SINIESTRO      FECHA      HORA     GRAVEDAD        CLASE CHOQUE_CON  \
# 0           4401423 2015-01-01  09:45:00  Con Heridos       Choque   Vehiculo
# 1           4401425 2015-01-01  13:25:00   Solo Daños       Choque   Vehiculo
# 2           4401430 2015-01-01  07:15:00  Con Heridos  Volcamiento        NaN
# 3           4401433 2015-01-01  20:30:00   Solo Daños       Choque   Vehiculo
# 4           4401437 2015-01-01  12:50:00   Solo Daños       Choque   Vehiculo
#
#   OBJETO_FIJO          DIRECCION  TOTAL_MUERTOS  TOTAL_HERIDOS  \
# 0         NaN    CL 66A-KR 76 02              0              2
# 1         NaN  CL 143A-KR 142 02              0              0
# 2         NaN  KR 19D-CL 62 S 02              0              1
# 3         NaN      AK 7-CL 43 33              0              0
# 4         NaN   DG 77A-AK 18D 02              0              0
#
#         LOCALIDAD  DISENO_LUGAR DIA_SEMANA  DIA_MES
# 0        Engativá  Interseccion   Thursday  January
# 1            Suba  Tramo de Via   Thursday  January
# 2  Ciudad Bolívar  Tramo de Via   Thursday  January
# 3       Chapinero  Tramo de Via   Thursday  January
# 4  Ciudad Bolívar  Tramo de Via   Thursday  January

# %% [markdown]
# Dia con mayor número de accidentes?

# %%
# función que recorre el dataframe y cuenta los accidentes que coincidan en un mes con el nombre de un dia a la semana
def Accidentes_por_mes(accidentes_siniestros, mes):
    lista_mes = []
    mon, tues, wed, thurs, fri, sat, sun = 0,0,0,0,0,0,0

    for idx, row in accidentes_siniestros.iterrows():
        if row["DIA_MES"] == mes and row["DIA_SEMANA"] == "Monday": mon +=1
        elif row["DIA_MES"] == mes and row["DIA_SEMANA"] == "Tuesday": tues +=1
        elif row["DIA_MES"] == mes and row["DIA_SEMANA"] == "Wednesday": wed +=1
        elif row["DIA_MES"] == mes and row["DIA_SEMANA"] == "Thursday": thurs +=1
        elif row["DIA_MES"] == mes and row["DIA_SEMANA"] == "Friday": fri +=1
        elif row["DIA_MES"] == mes and row["DIA_SEMANA"] == "Saturday": sat +=1
        elif row["DIA_MES"] == mes and row["DIA_SEMANA"] == "Sunday": sun +=1
        else: a=0

    lista_mes.append(mon)
    lista_mes.append(tues)
    lista_mes.append(wed)
    lista_mes.append(thurs)
    lista_mes.append(fri)
    lista_mes.append(sat)
    lista_mes.append(sun)

    total = mon+tues+wed+thurs+fri+sat+sun

    return(lista_mes)

# %%
january = Accidentes_por_mes(accidentes_siniestros, "January")
february = Accidentes_por_mes(accidentes_siniestros, "February")
march = Accidentes_por_mes(accidentes_siniestros, "March")
april = Accidentes_por_mes(accidentes_siniestros, "April")
may = Accidentes_por_mes(accidentes_siniestros, "May")
june = Accidentes_por_mes(accidentes_siniestros, "June")
july = Accidentes_por_mes(accidentes_siniestros, "July")
august = Accidentes_por_mes(accidentes_siniestros, "August")
september = Accidentes_por_mes(accidentes_siniestros, "September")
october = Accidentes_por_mes(accidentes_siniestros, "October")
november = Accidentes_por_mes(accidentes_siniestros, "November")
december = Accidentes_por_mes(accidentes_siniestros, "December")

# %%
columns = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]
rows = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre']
data = np.array([january, february, march, april, may, june, july, august, september, october, november, december])
heatmap_df = pd.DataFrame(data=data, index=rows, columns=columns)

# %%
heatmap_df
# Out:
#             Lunes  Martes  Miércoles  Jueves  Viernes  Sábado  Domingo
# Enero        1616    1888       1787    1666     1838    1718     1104
# Febrero      2133    2052       2111    1827     2215    2125     1331
# Marzo        1857    2337       2203    2332     2580    2226     1428
# Abril        2216    2112       2054    1993     2215    2174     1422
# Mayo         2095    2481       2379    2438     2498    2219     1476
# Junio        1663    2141       2125    2256     2411    2202     1338
# Julio        2089    2296       2115    2011     2309    2167     1480
# Agosto       2000    2352       2304    2379     2361    2181     1337
# Septiembre   2025    2159       2155    2219     2498    2303     1536
# Octubre      2131    2449       2299    2233     2300    2318     1474
# Noviembre    1820    2426       2313    2312     2414    2233     1426
# Diciembre    2175    2169       2103    2197     2234    2288     1571

# %% [markdown]
# Mes con mayor cantidad de accidentes

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,12))
map1 = sns.heatmap(heatmap_df, annot=True, fmt="d", cmap='BuPu', cbar_kws={"orientation": "horizontal"} )
map1.set_title("Accidentes de tráfico por mes en Bogotá 2015-2019")
plt.savefig("Imagenes/Accidentes_por_mes.jpg")

# %% [markdown]
# Dia con mayor cantidad de accidentes

# %%
# Se saca el numero de la hora, para graficar posteriormente
accidentes_siniestros["NUM_HORA"] = pd.to_datetime(accidentes_siniestros['HORA'], format='%H:%M:%S').dt.hour
accidentes_siniestros.head()
# Out:
#    CODIGO_SINIESTRO      FECHA      HORA     GRAVEDAD        CLASE CHOQUE_CON  \
# 0           4401423 2015-01-01  09:45:00  Con Heridos       Choque   Vehiculo
# 1           4401425 2015-01-01  13:25:00   Solo Daños       Choque   Vehiculo
# 2           4401430 2015-01-01  07:15:00  Con Heridos  Volcamiento        NaN
# 3           4401433 2015-01-01  20:30:00   Solo Daños       Choque   Vehiculo
# 4           4401437 2015-01-01  12:50:00   Solo Daños       Choque   Vehiculo
#
#   OBJETO_FIJO          DIRECCION  TOTAL_MUERTOS  TOTAL_HERIDOS  \
# 0         NaN    CL 66A-KR 76 02              0              2
# 1         NaN  CL 143A-KR 142 02              0              0
# 2         NaN  KR 19D-CL 62 S 02              0              1
# 3         NaN      AK 7-CL 43 33              0              0
# 4         NaN   DG 77A-AK 18D 02              0              0
#
#         LOCALIDAD  DISENO_LUGAR DIA_SEMANA  DIA_MES  NUM_HORA
# 0        Engativá  Interseccion   Thursday  January         9
# 1            Suba  Tramo de Via   Thursday  January        13
# 2  Ciudad Bolívar  Tramo de Via   Thursday  January         7
# 3       Chapinero  Tramo de Via   Thursday  January        20
# 4  Ciudad Bolívar  Tramo de Via   Thursday  January        12

# %%
def Accidentes_por_hora(accidentes_siniestros, hora):
    lista_horas = []
    mon, tues, wed, thurs, fri, sat, sun = 0,0,0,0,0,0,0

    for idx, row in accidentes_siniestros.iterrows():
        if row["NUM_HORA"] == hora and row["DIA_SEMANA"] == "Monday": mon +=1
        elif row["NUM_HORA"] == hora and row["DIA_SEMANA"] == "Tuesday": tues +=1
        elif row["NUM_HORA"] == hora and row["DIA_SEMANA"] == "Wednesday": wed +=1
        elif row["NUM_HORA"] == hora and row["DIA_SEMANA"] == "Thursday": thurs +=1
        elif row["NUM_HORA"] == hora and row["DIA_SEMANA"] == "Friday": fri +=1
        elif row["NUM_HORA"] == hora and row["DIA_SEMANA"] == "Saturday": sat +=1
        elif row["NUM_HORA"] == hora and row["DIA_SEMANA"] == "Sunday": sun +=1
        else: a=0

    lista_horas.append(mon)
    lista_horas.append(tues)
    lista_horas.append(wed)
    lista_horas.append(thurs)
    lista_horas.append(fri)
    lista_horas.append(sat)
    lista_horas.append(sun)

    total = mon+tues+wed+thurs+fri+sat+sun

    return(lista_horas)

# %%
hora_0 = Accidentes_por_hora(accidentes_siniestros, 0)
hora_1 = Accidentes_por_hora(accidentes_siniestros, 1)
hora_2 = Accidentes_por_hora(accidentes_siniestros, 2)
hora_3 = Accidentes_por_hora(accidentes_siniestros, 3)
hora_4 = Accidentes_por_hora(accidentes_siniestros, 4)
hora_5 = Accidentes_por_hora(accidentes_siniestros, 5)
hora_6 = Accidentes_por_hora(accidentes_siniestros, 6)
hora_7 = Accidentes_por_hora(accidentes_siniestros, 7)
hora_8 = Accidentes_por_hora(accidentes_siniestros, 8)
hora_9 = Accidentes_por_hora(accidentes_siniestros, 9)
hora_10 = Accidentes_por_hora(accidentes_siniestros, 10)
hora_11 = Accidentes_por_hora(accidentes_siniestros, 11)
hora_12 = Accidentes_por_hora(accidentes_siniestros, 12)
hora_13 = Accidentes_por_hora(accidentes_siniestros, 13)
hora_14 = Accidentes_por_hora(accidentes_siniestros, 14)
hora_15 = Accidentes_por_hora(accidentes_siniestros, 15)
hora_16 = Accidentes_por_hora(accidentes_siniestros, 16)
hora_17 = Accidentes_por_hora(accidentes_siniestros, 17)
hora_18 = Accidentes_por_hora(accidentes_siniestros, 18)
hora_19 = Accidentes_por_hora(accidentes_siniestros, 19)
hora_20 = Accidentes_por_hora(accidentes_siniestros, 20)
hora_21 = Accidentes_por_hora(accidentes_siniestros, 21)
hora_22 = Accidentes_por_hora(accidentes_siniestros, 22)
hora_23 = Accidentes_por_hora(accidentes_siniestros, 23)
hora_24 = Accidentes_por_hora(accidentes_siniestros, 24)

# %%
#Create matrix for the heatmap
columns = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]
rows = ["0", "1am", "2am", "3am", "4am", "5am", "6am", "7am", "8am", "9am", "10am", "11am", "12pm", "1pm", "2pm", "3pm","4pm","5pm","6pm","7pm","8pm","9pm","10pm","11pm"]
data = np.array([hora_0, hora_1, hora_2, hora_3, hora_4, hora_5, hora_6, hora_7, hora_8, hora_9, hora_10, hora_11, hora_12, hora_13, hora_14, hora_15, hora_16, hora_17, hora_18, hora_19, hora_20, hora_21, hora_22, hora_23])
heatmap_hora = pd.DataFrame(data=data, index=rows, columns=columns)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,12))
ax = sns.heatmap(heatmap_hora, annot=True, fmt="d", cmap='BuPu', cbar_kws={"orientation": "horizontal"} )
ax.set_title("Accidentes de tráfico por mes en Bogotá 2015-2019")
plt.savefig("Imagenes/Accidentes_por_hora.jpg")
